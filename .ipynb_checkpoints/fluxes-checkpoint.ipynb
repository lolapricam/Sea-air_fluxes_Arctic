# %% [markdown]
# # Main Code

# %%
# Installing packages
#!pip install pandas openpyxl
# Out:
# ...
#   Using cached openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# ...
#   Using cached et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# ...
# Using cached openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Using cached et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# ...

# %%
# Loading packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import matplotlib.colors as mcolors
import matplotlib.cm as cm
import os
import seaborn as sns

# %% [markdown]
# ## Loading data files

# %%
# Loading data
data = pd.read_excel("Data/Data_final.xlsx") 

# Display the first 5 rows
print(data.head())

metadata = pd.read_excel("Data/Metadata_final.xlsx") 

# Display the first 5 rows  
print(metadata.head())
# Out:
#          Sample_Name  SeaDistance_m Location Duplicate    Datetime   Latitude  \
# 0  SLWT_2024_01_19_A            NaN    shore         A  2024_01_19  16.625000
# 1  SLWT_2024_01_19_B            NaN    shore         B  2024_01_19  16.625000
# 2  SLWT_2024_01_20_A            NaN    shore         A  2024_01_20  16.401667
# 3  SLWT_2024_01_20_B            NaN    shore         B  2024_01_20  16.401667
# 4  SLWT_2024_01_21_A            NaN    shore         A  2024_01_21  16.316667
#
#    Longitude  Type  HP_12CH4_dry_mean  HR_12CH4_dry_mean  ...  AirT_degC  \
# 0 -25.325000   NaN           1.854859           1.838359  ...       24.5
# 1 -25.325000   NaN           1.729128           1.715480  ...       24.5
# 2 -27.518333   NaN           1.827733           1.818951  ...       23.5
# 3 -27.518333   NaN           1.892697           1.893364  ...       23.5
# 4 -30.581667   NaN           1.902200           1.882740  ...       25.0
#
# ...

# %%
#change of units for CH4: mmol/m3 --> umol/m3
data['ch4_umolm3'] = data['ch4_mmolm3'] * 10**3 
print(data.head())
# Out:
#          Sample_Name  SeaDistance_m Location Duplicate    Datetime   Latitude  \
# 0  SLWT_2024_01_19_A            NaN    shore         A  2024_01_19  16.625000
# 1  SLWT_2024_01_19_B            NaN    shore         B  2024_01_19  16.625000
# 2  SLWT_2024_01_20_A            NaN    shore         A  2024_01_20  16.401667
# 3  SLWT_2024_01_20_B            NaN    shore         B  2024_01_20  16.401667
# 4  SLWT_2024_01_21_A            NaN    shore         A  2024_01_21  16.316667
#
#    Longitude  Type  HP_12CH4_dry_mean  HR_12CH4_dry_mean  ...  AirP_hPa  \
# 0 -25.325000   NaN           1.854859           1.838359  ...    1016.0
# 1 -25.325000   NaN           1.729128           1.715480  ...    1016.0
# 2 -27.518333   NaN           1.827733           1.818951  ...    1014.7
# 3 -27.518333   NaN           1.892697           1.893364  ...    1014.7
# 4 -30.581667   NaN           1.902200           1.882740  ...    1014.9
#
# ...

# %% [markdown]
# ## Loading Variables

# %%
# Some usefull variables

R_JKmol = 8.314 # [J/K/mol], ideal gas law
V_w_L = 0.105 #[L], volume of the water sample in the syringe
V_hs_L = 0.35 #[L], volume of the headspace in the syringe
V_tot_L = 0.140 #[L], volume total of the syringe
P_atm_Pa = 101325 #[Pa], atmospheric pressure
M_C_gmol = 12 #[g/mol], molare mass of C

# %% [markdown]
# ## Calculation of ocean-air fluxes for CO2 and methane

# %% [markdown]
# ### Partial pressure - Pi [Pa]

# %%
# CO2
Pi_CO2_Pa = data["CO2atm_ppm"] * 10**(-6) * P_atm_Pa
print(Pi_CO2_Pa)

#CH4
Pi_CH4_Pa = data["CH4atm_ppm"] * 10**(-6) * P_atm_Pa
#print(Pi_CH4_Pa)
# Out:
# 0     43.958510
# 1     43.958510
# 2     38.189018
# 3     38.189018
# 4     45.106187
# 5     45.106187
# 6     43.956948
# 7     43.956948
# 8     44.130671
# 9     44.130671
# 10    43.158176
# 11    43.958510
# 12    43.958510
# 13    40.727453
# 14    40.727453
# 15    43.203416
# 16    43.203416
# 17    43.987442
# 18    45.921049
# 19    45.921049
# 20    45.921049
# 21    46.712197
# 22    45.791129
# 23    45.791129
# 24    44.870060
# 25    47.539500
# 26    47.539500
# 27    43.433022
# 28    43.433022
# 29    41.461146
# 30    43.156425
# 31    43.156425
# 32    43.739954
# 33    43.739954
# 34    43.598836
# 35    43.598836
# 36    43.097132
# 37    43.097132
# 38    44.138027
# 39    42.662626
# 40    42.662626
# 41    44.534016
# 42    44.534016
# 43    42.374611
# 44    42.713701
# 45    42.713701
# 46    42.493268
# 47    42.745527
# 48    42.745527
# Name: CO2atm_ppm, dtype: float64

# %% [markdown]
# ### Gas concentration in the water - n [mol]

# %%
#convert Temp at equilibrium (assumed to be the Temp after shaking) in Kelvin
Te_K = data["Te_degC"] + 273.15 
#print(Te_K)

# %%
# Ideal Gas Law (Magen et al., 2014) 
#converting V_w_L in m3
V_w_m3 = V_w_L / 1000

n_CO2_mol = Pi_CO2_Pa * V_w_m3 / (R_JKmol * Te_K)
#print(n_CO2_mol)

n_CH4_mol = Pi_CH4_Pa * V_w_m3 / (R_JKmol * Te_K)
#print(n_CH4_mol)

# %% [markdown]
# ### Corrected Henry's coefficients [mol/m3/Pa]

# %%
# CO2 (Weiss 1974)
A = [-58.0931, 90.5069, 22.2940]
B = [0.027766, -0.025888, 0.0050578]
hcpsalt_CO2_molm3Pa = (
    np.exp(
    A[0]
    + A[1] * 100 / Te_K
    + A[2] * np.log(Te_K / 100)
    + data["sal_psu"] * (B[0] + B[1] * Te_K / 100 + B[2] * (Te_K / 100) ** 2)
    ) * 1000/ 101325 
    )
print(hcpsalt_CO2_molm3Pa)
# Out:
# 0     0.000296
# 1     0.000296
# 2     0.000282
# 3     0.000284
# 4     0.000283
# 5     0.000287
# 6     0.000256
# 7     0.000265
# 8     0.000266
# 9     0.000265
# 10    0.000273
# 11    0.000271
# 12    0.000269
# 13    0.000269
# 14    0.000269
# 15    0.000264
# 16    0.000266
# 17    0.000267
# 18    0.000267
# 19    0.000267
# 20    0.000269
# 21    0.000262
# 22    0.000262
# 23    0.000264
# 24    0.000263
# 25    0.000260
# 26    0.000260
# 27    0.000490
# 28    0.000490
# 29    0.000475
# 30    0.000468
# 31    0.000466
# 32    0.000485
# 33    0.000491
# 34    0.000571
# 35    0.000573
# 36    0.000440
# 37    0.000437
# 38    0.000435
# 39    0.000496
# 40    0.000496
# 41    0.000482
# 42    0.000472
# 43    0.000567
# 44    0.000517
# 45    0.000517
# 46    0.000501
# 47    0.000524
# 48    0.000508
# dtype: float64

# %%
# CH4 (Wiesenburg and Guinasso 1979)
A = [-417.5053, 599.8626, 380.3636, -62.0764]
B = [-0.064236, 0.03498, -0.0052732]
c_molm3 = (
    np.exp(
    + A[0]
    + A[1] * 100 / Te_K
    + A[2] * np.log(Te_K / 100)
    + A[3] * (Te_K / 100)
    + data["sal_psu"] * (B[0] + B[1] * Te_K / 100 + B[2] * (Te_K / 100) ** 2)
    ) * 1000 / 1e9
    )

hcpsalt_CH4_molm3Pa = c_molm3 / 101325

#print(hcpsalt__CH4_molm3Pa)

# %% [markdown]
# ### Equilibrium concentration [mol/m3] or solubility of the gases

# %%
# Henry’s Law (Sander, 2023)
# CO2
C_eq_CO2_molm3 = hcpsalt_CO2_molm3Pa * Pi_CO2_Pa
print(C_eq_CO2_molm3)

# CH4
C_eq_CH4_molm3 = hcpsalt_CH4_molm3Pa * Pi_CH4_Pa
#print(C_eq_CH4_molm3)
# Out:
# 0     0.013029
# 1     0.013029
# 2     0.010776
# 3     0.010831
# 4     0.012757
# 5     0.012954
# 6     0.011249
# 7     0.011630
# 8     0.011735
# 9     0.011679
# 10    0.011766
# 11    0.011925
# 12    0.011809
# 13    0.010942
# 14    0.010942
# 15    0.011422
# 16    0.011505
# 17    0.011729
# 18    0.012247
# 19    0.012247
# 20    0.012337
# 21    0.012236
# 22    0.011992
# 23    0.012078
# 24    0.011781
# 25    0.012359
# 26    0.012359
# 27    0.021272
# 28    0.021272
# 29    0.019713
# 30    0.020196
# 31    0.020127
# 32    0.021194
# 33    0.021490
# 34    0.024881
# 35    0.024973
# 36    0.018967
# 37    0.018843
# 38    0.019187
# 39    0.021174
# 40    0.021174
# 41    0.021470
# 42    0.021034
# 43    0.024007
# 44    0.022081
# 45    0.022081
# 46    0.021290
# 47    0.022407
# 48    0.021702
# dtype: float64

# %%
# Check if equilibrium concentration is correct
H_ref = 3.4 * 10**(-4) #mol/m3/Pa
T_ref = 298.15 #K
B = 2300 #K
T = np.array([273, 283, 293, 303])

Hs = H_ref * np.exp(B * (1/T - 1/T_ref)) * 10**3 #mmol/m3/Pa
Pi_CO2 = 430 * 10**(-6) * P_atm_Pa
C_eq = Hs * Pi_CO2

print(Hs)
print(C_eq)
# Out:
# [0.69202096 0.51384224 0.38937277 0.30050575]
# [30.15118018 22.38797807 16.96487436 13.09296047]

# %% [markdown]
# ### Gas transfer velocity K600 [m/d]

# %%
# Function to extract min and max wind speed
kts_to_ms = 1852 / 3600

def WS_min_max(wind_speed):
    if isinstance(wind_speed, str) and '-' in wind_speed:  # Check if it's a range
        min_val, max_val = map(float, wind_speed.split('-'))  # Split and convert to float
    else:
        min_val = max_val = float(wind_speed)  # If it's a single number
    return pd.Series([min_val, max_val])

# Apply function to create new columns
metadata[['Min_Wind_Speed [kts]', 'Max_Wind_Speed [kts]']] = metadata['TWS [kts]'].apply(WS_min_max)

# Convert knots to meters per second
metadata['Min_Wind_Speed [m/s]'] = metadata['Min_Wind_Speed [kts]'] * kts_to_ms
metadata['Max_Wind_Speed [m/s]'] = metadata['Max_Wind_Speed [kts]'] * kts_to_ms

# Display the first rows
print(metadata.head())
# Out:
#          Sample_Name   Latitude  Longitude TWS [kts]  SOG [kts]  P_atm [hPa]  \
# 0  SLWT_2024_01_19_A  16.625000 -25.325000         7        4.5       1016.0
# 1  SLWT_2024_01_19_B  16.625000 -25.325000         7        4.5       1016.0
# 2  SLWT_2024_01_20_A  16.401667 -27.518333        16        7.6       1014.7
# 3  SLWT_2024_01_20_B  16.401667 -27.518333        16        7.6       1014.7
# 4  SLWT_2024_01_21_A  16.316667 -30.581667        19        7.5       1014.9
#
#    T_air [°C]   pH  Tw_b [°C]  Tw_a [°C] Mer [Douglas]  \
# 0        24.5  7.5       24.0       23.5             3
# 1        24.5  7.5       23.5       23.5             3
# 2        23.5  7.5       24.8       25.4           3-4
# 3        23.5  7.5       24.5       25.2           3-4
# 4        25.0  7.5       24.7       25.3             3
#
#                            Remarks  Min_Wind_Speed [kts]  \
# 0  Air pressure from NOAA archives                   7.0
# ...

# %%
# Calculation of the gas transfer velocity K600 (MacIntyre et al., 2010) 
K600_min_md = (2.04 * metadata["Min_Wind_Speed [m/s]"] + 2.0) * 0.24 # conversion from cm/h to m/d
print(K600_min_md)

K600_max_md = (2.04 * metadata["Max_Wind_Speed [m/s]"] + 2.0) * 0.24 # conversion from cm/h to m/d
#print(K600_max_md)
# Out:
# 0     2.243104
# 1     2.243104
# 2     4.509952
# 3     4.509952
# 4     5.265568
# 5     5.265568
# 6     3.603213
# 7     3.603213
# 8     4.006208
# 9     4.006208
# 10    3.250592
# 11    3.754336
# 12    3.754336
# 13    3.250592
# 14    3.250592
# 15    4.006208
# 16    4.006208
# 17    4.761824
# 18    4.258080
# 19    4.258080
# 20    4.258080
# 21    3.502464
# 22    3.250592
# 23    3.250592
# 24    3.250592
# 25    3.250592
# 26    3.250592
# 27    2.494976
# 28    2.494976
# 29    1.739360
# 30    1.739360
# 31    1.739360
# 32    8.036160
# 33    8.036160
# 34    4.258080
# 35    4.258080
# 36    2.494976
# 37    2.494976
# 38    0.983744
# 39    3.502464
# 40    3.502464
# 41    0.983744
# 42    0.983744
# 43    4.258080
# 44    1.739360
# 45    1.739360
# 46    0.983744
# 47    0.731872
# 48    0.731872
# Name: Min_Wind_Speed [m/s], dtype: float64

# %% [markdown]
# ### Schmidt number - Sc [-]

# %%
# (Wanninkhof, 2014) - temperature of the water in °C
#CO2
Sc_CO2 =  2073.1 - 125.62 * metadata["Tw_b [°C]"] + 3.6276 * metadata["Tw_b [°C]"]**2 - 0.043219 * metadata["Tw_b [°C]"]**3
#print(Sc_CO2)

#CH4
Sc_CH4 = 2039.2 - 120.31 * metadata["Tw_b [°C]"] + 3.4209 * metadata["Tw_b [°C]"]**2 - 0.040437 * metadata["Tw_b [°C]"]**3
#print(Sc_CH4)

# %% [markdown]
# ### Exchange coefficient - Ki [m/d]

# %%
# Define n from the gas exchange equation (n = 0.5 for wind speeds > 3.7 [m s-1] or, n = 0.66 for wind speeds < 3.7 [m s-1]) :
def WS_n (wind_speed) :
    if wind_speed < 3.7 :
        n = 0.66
    else:
        n = 0.5
    return n

metadata['Min_n'] = metadata['Min_Wind_Speed [m/s]'].apply(WS_n)
metadata['Max_n'] = metadata['Max_Wind_Speed [m/s]'].apply(WS_n)

print(metadata.head())
# Out:
#          Sample_Name   Latitude  Longitude TWS [kts]  SOG [kts]  P_atm [hPa]  \
# 0  SLWT_2024_01_19_A  16.625000 -25.325000         7        4.5       1016.0
# 1  SLWT_2024_01_19_B  16.625000 -25.325000         7        4.5       1016.0
# 2  SLWT_2024_01_20_A  16.401667 -27.518333        16        7.6       1014.7
# 3  SLWT_2024_01_20_B  16.401667 -27.518333        16        7.6       1014.7
# 4  SLWT_2024_01_21_A  16.316667 -30.581667        19        7.5       1014.9
#
#    T_air [°C]   pH  Tw_b [°C]  Tw_a [°C] Mer [Douglas]  \
# 0        24.5  7.5       24.0       23.5             3
# 1        24.5  7.5       23.5       23.5             3
# 2        23.5  7.5       24.8       25.4           3-4
# 3        23.5  7.5       24.5       25.2           3-4
# 4        25.0  7.5       24.7       25.3             3
#
#                            Remarks  Min_Wind_Speed [kts]  \
# 0  Air pressure from NOAA archives                   7.0
# ...

# %%
# Find indices where Min and Max n are different
indices = metadata[metadata["Min_n"] != metadata["Max_n"]].index
print(indices)
# Out:
# Index([29], dtype='int64')

# %%
# Gas exchange for CO2 (McGinnis et al., 2015) 
Ki_min_CO2_md = K600_min_md * (600 / Sc_CO2)**(-metadata["Min_n"])
#print(Ki_min_CO2_md)

Ki_max_CO2_md = K600_max_md * (600 / Sc_CO2)**(-metadata["Max_n"])
#print(Ki_max_CO2_md)

# %%
# Gas exchange for CH4 (McGinnis et al., 2015) 
Ki_min_CH4_md = K600_min_md * (600 / Sc_CH4)**(-metadata["Min_n"])
#print(Ki_min_CH4_md)

Ki_max_CH4_md = K600_max_md * (600 / Sc_CH4)**(-metadata["Max_n"])
#print(Ki_max_CH4_md)

# %% [markdown]
# ### Ocean-air fluxes - F [mmol/m2/d]

# %%
#Fick’s first law for CO2 (Fick, 1855) 
F_min_CO2_mmolm2d = Ki_min_CO2_md * (data["co2_mmolm3"] - C_eq_CO2_molm3 * 10**3)
F_max_CO2_mmolm2d = Ki_max_CO2_md * (data["co2_mmolm3"] - C_eq_CO2_molm3 * 10**3)
F_mean_CO2_mmolm2d = np.mean([F_min_CO2_mmolm2d, F_max_CO2_mmolm2d], axis = 0)

df = pd.DataFrame({'Min CO2 flux': F_min_CO2_mmolm2d, 'Max CO2 flux': F_max_CO2_mmolm2d, 'Mean CO2 flux' : F_mean_CO2_mmolm2d })
display(df)
# Out:
#     Min CO2 flux  Max CO2 flux  Mean CO2 flux
# 0       8.184870      8.184870       8.184870
# 1      15.599036     15.599036      15.599036
# 2      15.219398     15.219398      15.219398
# 3      15.805153     15.805153      15.805153
# 4       1.376227      1.376227       1.376227
# 5       3.745745      3.745745       3.745745
# 6       6.687741      6.687741       6.687741
# 7       5.564639      5.564639       5.564639
# 8       4.166852      4.166852       4.166852
# 9       1.735661      1.735661       1.735661
# 10      1.067636      1.067636       1.067636
# 11      1.648564      1.648564       1.648564
# 12      7.310499      7.310499       7.310499
# 13      4.128738      4.128738       4.128738
# 14      5.485995      5.485995       5.485995
# 15      4.168782      4.168782       4.168782
# 16      5.617023      5.617023       5.617023
# 17      0.242258      0.242258       0.242258
# 18      0.588781      0.588781       0.588781
# ...

# %%
#Fick’s first law for CH4 (Fick, 1855)
F_min_CH4_umolm2d = Ki_min_CH4_md * (data["ch4_mmolm3"] - C_eq_CH4_molm3 * 10**(3)) * 10**3
F_max_CH4_umolm2d = Ki_max_CH4_md * (data["ch4_mmolm3"] - C_eq_CH4_molm3 * 10**(3)) * 10**3
F_mean_CH4_umolm2d = np.mean([F_min_CH4_umolm2d, F_max_CH4_umolm2d], axis = 0)

df = pd.DataFrame({'Min CH4 flux': F_min_CH4_umolm2d, 'Max CH4 flux': F_max_CH4_umolm2d, 'Mean CH4 flux' : F_mean_CH4_umolm2d})
display(df)
# Out:
#     Min CH4 flux  Max CH4 flux  Mean CH4 flux
# 0       2.327666      2.327666       2.327666
# 1      -1.810165     -1.810165      -1.810165
# 2      10.796398     10.796398      10.796398
# 3      15.182311     15.182311      15.182311
# 4       5.818389      5.818389       5.818389
# 5       5.871222      5.871222       5.871222
# 6       1.051704      1.051704       1.051704
# 7       2.324586      2.324586       2.324586
# 8       1.488210      1.488210       1.488210
# 9      -2.296694     -2.296694      -2.296694
# 10      0.092374      0.092374       0.092374
# 11      3.455896      3.455896       3.455896
# 12      1.452814      1.452814       1.452814
# 13      2.963796      2.963796       2.963796
# 14      4.779076      4.779076       4.779076
# 15      2.785456      2.785456       2.785456
# 16      3.339873      3.339873       3.339873
# 17      3.322648      3.322648       3.322648
# 18      2.345068      2.345068       2.345068
# ...

# %% [markdown]
# ### Creating dataframe with all the results

# %%
# Creating a big datafrane with all the results
# for CO2
df_CO2 = pd.DataFrame({'Datetime' : data["Datetime"], 'Lat' : data["Latitude"], 'Long' : data["Longitude"],  'Pi CO2 [Pa]' : Pi_CO2_Pa, 'n CO2 [mol]' : n_CO2_mol, 'Henrys coeff [molm3Pa] ' : hcpsalt_CO2_molm3Pa, 
                   'C_eq CO2 [molm3]' : C_eq_CO2_molm3, 'Min K600 [m/d]' : K600_min_md, 'Max K600 [m/d]' : K600_max_md,
                   'Sc CO2 [-]' : Sc_CO2, 'Min Ki CO2 [m/d]' : Ki_min_CO2_md, 'Max Ki CO2 [m/d]' : Ki_max_CO2_md,  
                   'Min CO2 flux [mmol/m2/d]': F_min_CO2_mmolm2d, 'Max CO2 flux [mmol/m2/d]': F_max_CO2_mmolm2d, 'Mean CO2 flux [mmol/m2/d]' : F_mean_CO2_mmolm2d})
display(df_CO2)
# Out:
#       Datetime        Lat       Long  Pi CO2 [Pa]  n CO2 [mol]  \
# 0   2024_01_19  16.625000 -25.325000    43.958510     0.000002
# 1   2024_01_19  16.625000 -25.325000    43.958510     0.000002
# 2   2024_01_20  16.401667 -27.518333    38.189018     0.000002
# 3   2024_01_20  16.401667 -27.518333    38.189018     0.000002
# 4   2024_01_21  16.316667 -30.581667    45.106187     0.000002
# 5   2024_01_21  16.316667 -30.581667    45.106187     0.000002
# 6   2024_01_22  16.036667 -33.103333    43.956948     0.000002
# 7   2024_01_22  16.036667 -33.103333    43.956948     0.000002
# 8   2024_01_23  15.370000 -35.616667    44.130671     0.000002
# 9   2024_01_23  15.370000 -35.616667    44.130671     0.000002
# 10  2024_01_24  13.746667 -37.530000    43.158176     0.000002
# 11  2024_01_25  13.190000 -39.933333    43.958510     0.000002
# 12  2024_01_25  13.190000 -39.933333    43.958510     0.000002
# 13  2024_01_26  13.230000 -42.148333    40.727453     0.000002
# ...

# %%
# for CH4
df_CH4 = pd.DataFrame({'Datetime' : data["Datetime"], 'Lat' : data["Latitude"], 'Long' : data["Longitude"], 'Pi CH4 [Pa]' : Pi_CH4_Pa, 'n CH4 [mol]' : n_CH4_mol, 'Henrys coeff CH4 [molm3Pa] ' : hcpsalt_CH4_molm3Pa, 
                   'C_eq CH4 [molm3]' : C_eq_CH4_molm3, 'Min K600 [m/d]' : K600_min_md, 'Max K600 [m/d]' : K600_max_md,
                   'Sc CH4 [-]' : Sc_CH4, 'Min Ki CH4 [m/d]' : Ki_min_CH4_md, 'Max Ki CH4 [m/d]' : Ki_max_CH4_md,  
                   'Min CH4 flux [umol/m2/d]': F_min_CH4_umolm2d, 'Max CH4 flux [umol/m2/d]': F_max_CH4_umolm2d, 'Mean CH4 flux [umol/m2/d]' : F_mean_CH4_umolm2d})
display(df_CH4)
# Out:
#       Datetime        Lat       Long  Pi CH4 [Pa]   n CH4 [mol]  \
# 0   2024_01_19  16.625000 -25.325000     0.185789  7.909599e-09
# 1   2024_01_19  16.625000 -25.325000     0.185789  7.909599e-09
# 2   2024_01_20  16.401667 -27.518333     0.171231  7.243424e-09
# 3   2024_01_20  16.401667 -27.518333     0.171231  7.248280e-09
# 4   2024_01_21  16.316667 -30.581667     0.189187  8.005712e-09
# 5   2024_01_21  16.316667 -30.581667     0.189187  8.021839e-09
# 6   2024_01_22  16.036667 -33.103333     0.189799  7.922750e-09
# 7   2024_01_22  16.036667 -33.103333     0.189799  7.959581e-09
# 8   2024_01_23  15.370000 -35.616667     0.190664  8.001154e-09
# 9   2024_01_23  15.370000 -35.616667     0.190664  7.995840e-09
# 10  2024_01_24  13.746667 -37.530000     0.188566  7.939503e-09
# 11  2024_01_25  13.190000 -39.933333     0.185789  7.817366e-09
# 12  2024_01_25  13.190000 -39.933333     0.185789  7.806962e-09
# 13  2024_01_26  13.230000 -42.148333     0.183963  7.730235e-09
# ...

# %% [markdown]
# ## Calculation of some mean values

# %% [markdown]
# ### Fluxes

# %%
#CO2
#overrall mean values
#mean_F_min_CO2_mmolm2d = np.mean(F_min_CO2_mmolm2d)
#mean_F_max_CO2_mmolm2d = np.mean(F_max_CO2_mmolm2d)
mean_F_mean_CO2_mmolm2d = np.mean(F_mean_CO2_mmolm2d)
std_dev_mean_F_mean_CO2_mmolm2d = np.std(F_mean_CO2_mmolm2d, ddof=1)
#print("Mean min CO2 flux:", mean_F_min_CO2_mmolm2d.round(2), "mmol/m2/d")
#print("Mean max CO2 flux:", mean_F_max_CO2_mmolm2d.round(2), "mmol/m2/d")
print("Mean mean CO2 flux:", mean_F_mean_CO2_mmolm2d.round(2), "mmol/m2/d +/-", round(std_dev_mean_F_mean_CO2_mmolm2d, 2), "mmol/m2/d",  "\n")

#mean value of transatlantic samples
#mean_F_min_CO2_transat = np.mean(F_min_CO2_mmolm2d[0:27])
#mean_F_max_CO2_transat = np.mean(F_max_CO2_mmolm2d[0:27])
mean_F_mean_CO2_transat = np.mean(F_mean_CO2_mmolm2d[0:27])
std_dev_mean_F_mean_CO2_mmolm2d_transat = np.std(F_mean_CO2_mmolm2d[0:27], ddof=1)
#print("Transatlantic mean min CO2 flux:", mean_F_min_CO2_transat.round(2), "mmol/m2/d")
#print("Transatlantic mean max CO2 flux:", mean_F_max_CO2_transat.round(2), "mmol/m2/d")
print("Transatlantic mean mean CO2 flux:", mean_F_mean_CO2_transat.round(2), "mmol/m2/d +/-", round(std_dev_mean_F_mean_CO2_mmolm2d_transat, 2), "mmol/m2/d", "\n")

#mean value of Labrador sea samples
#mean_F_min_CO2_labrador = np.mean(F_min_CO2_mmolm2d[27:36])
#mean_F_max_CO2_labrador = np.mean(F_max_CO2_mmolm2d[27:36])
mean_F_mean_CO2_labrador = np.mean(F_mean_CO2_mmolm2d[27:36])
std_dev_mean_F_mean_CO2_mmolm2d_labrador = np.std(F_mean_CO2_mmolm2d[27:36], ddof=1)
#print("Labrador sea mean min CO2 flux:", mean_F_min_CO2_labrador.round(2), "mmol/m2/d")
#print("Labrador sea mean max CO2 flux:", mean_F_max_CO2_labrador.round(2), "mmol/m2/d")
print("Labrador sea mean mean CO2 flux:", mean_F_mean_CO2_labrador.round(2), "mmol/m2/d +/-", round(std_dev_mean_F_mean_CO2_mmolm2d_labrador, 2), "mmol/m2/d", "\n")

#mean value of Greeanland samples
#mean_F_min_CO2_greenland = np.mean(F_min_CO2_mmolm2d[36:])
#mean_F_max_CO2_greenland = np.mean(F_max_CO2_mmolm2d[36:])
mean_F_mean_CO2_greenland = np.mean(F_mean_CO2_mmolm2d[36:])
std_dev_mean_F_mean_CO2_mmolm2d_greenland = np.std(F_mean_CO2_mmolm2d[36:], ddof=1)
#print("Greenland mean min CO2 flux:", mean_F_min_CO2_greenland.round(2), "mmol/m2/d")
#print("Greenland mean max CO2 flux:", mean_F_max_CO2_greenland.round(2), "mmol/m2/d")
print("Greenland mean mean CO2 flux:", mean_F_mean_CO2_greenland.round(2), "mmol/m2/d +/-", round(std_dev_mean_F_mean_CO2_mmolm2d_greenland, 2), "mmol/m2/d", "\n")

mean_F_mean_CO2_LS_and_G = np.mean(F_mean_CO2_mmolm2d[27:])
std_dev_mean_F_mean_CO2_mmolm2d_LS_and_G = np.std(F_mean_CO2_mmolm2d[27:], ddof=1)
print("Labrador + Greenland mean mean CO2 flux:", mean_F_mean_CO2_LS_and_G.round(2), "mmol/m2/d +/-", round(std_dev_mean_F_mean_CO2_mmolm2d_LS_and_G, 2), "mmol/m2/d")
# Out:
# Mean mean CO2 flux: -3.4 mmol/m2/d +/- 14.87 mmol/m2/d
#
# Transatlantic mean mean CO2 flux: 5.3 mmol/m2/d +/- 4.58 mmol/m2/d
#
# Labrador sea mean mean CO2 flux: -26.45 mmol/m2/d +/- 17.63 mmol/m2/d
#
# Greenland mean mean CO2 flux: -5.53 mmol/m2/d +/- 7.65 mmol/m2/d
#
# Labrador + Greenland mean mean CO2 flux: -14.09 mmol/m2/d +/- 16.21 mmol/m2/d

# %%
#CH4
#overall mean values
#mean_F_min_CH4_umolm2d = np.mean(F_min_CH4_umolm2d)
#mean_F_max_CH4_umolm2d = np.mean(F_max_CH4_umolm2d)
mean_F_mean_CH4_umolm2d = np.mean(F_mean_CH4_umolm2d)
std_dev_mean_F_mean_CH4_umolm2d = np.std(F_mean_CH4_umolm2d, ddof=1)
#print("Mean min CH4 flux:", mean_F_min_CH4_umolm2d.round(2), "umol/m2/d")
#print("Mean max CH4 flux:", mean_F_max_CH4_umolm2d.round(2), "umol/m2/d")
print("Mean mean CH4 flux:", mean_F_mean_CH4_umolm2d.round(2), "umol/m2/d +/-", round(std_dev_mean_F_mean_CH4_umolm2d, 2), "umol/m2/d", "\n")

#mean value of transatlantic samples
#mean_F_min_CH4_transat = np.mean(F_min_CH4_umolm2d[0:27])
#mean_F_max_CH4_transat = np.mean(F_max_CH4_umolm2d[0:27])
mean_F_mean_CH4_transat = np.mean(F_mean_CH4_umolm2d[0:27])
std_dev_mean_F_mean_CH4_umolm2d_transat = np.std(F_mean_CH4_umolm2d[0:27], ddof=1)
#print("Transatlantic mean min CH4 flux:", mean_F_min_CH4_transat.round(2), "umol/m2/d")
#print("Transatlantic mean max CH4 flux:", mean_F_max_CH4_transat.round(2),"umol/m2/d")
print("Transatlantic mean mean CH4 flux:", mean_F_mean_CH4_transat.round(2), "umol/m2/d +/-", round(std_dev_mean_F_mean_CH4_umolm2d_transat, 2), "umol/m2/d",  "\n")

#mean value of Labrador sea samples
#mean_F_min_CH4_labrador = np.mean(F_min_CH4_umolm2d[27:36])
#mean_F_max_CH4_labrador = np.mean(F_max_CH4_umolm2d[27:36])
mean_F_mean_CH4_labrador = np.mean(F_mean_CH4_umolm2d[27:36])
std_dev_mean_F_mean_CH4_umolm2d_labrador = np.std(F_mean_CH4_umolm2d[27:36], ddof=1)
#print("Labrador sea mean min CH4 flux:", mean_F_min_CH4_labrador.round(2), "umol/m2/d")
#print("Labrador sea mean max CH4 flux:", mean_F_max_CH4_labrador.round(2), "umol/m2/d")
print("Labrador sea mean mean CH4 flux:", mean_F_mean_CH4_labrador.round(2), "umol/m2/d +/-", round(std_dev_mean_F_mean_CH4_umolm2d_labrador, 2), "umol/m2/d", "\n")

#mean value of Greeanland samples
#mean_F_min_CH4_greenland = np.mean(F_min_CH4_umolm2d[36:])
#mean_F_max_CH4_greenland = np.mean(F_max_CH4_umolm2d[36:])
mean_F_mean_CH4_greenland = np.mean(F_mean_CH4_umolm2d[36:])
std_dev_mean_F_mean_CH4_umolm2d_greenland = np.std(F_mean_CH4_umolm2d[36:], ddof=1)
#print("Greenland mean min CH4 flux:", mean_F_min_CH4_greenland.round(2), "umol/m2/d")
#print("Greenland mean max CH4 flux:", mean_F_max_CH4_greenland.round(2), "umol/m2/d")
print("Greenland mean mean CH4 flux:", mean_F_mean_CH4_greenland.round(2), "umol/m2/d +/-", round(std_dev_mean_F_mean_CH4_umolm2d_greenland, 2), "umol/m2/d", '\n')

mean_F_mean_CH4_LS_and_G = np.mean(F_mean_CH4_umolm2d[27:])
std_dev_mean_F_mean_CH4_umolm2d_LS_and_g = np.std(F_mean_CH4_umolm2d[27:], ddof=1)
print("Labrador + Greenland mean mean CH4 flux:", mean_F_mean_CH4_LS_and_G.round(2), "umol/m2/d +/-", round(std_dev_mean_F_mean_CH4_umolm2d_LS_and_g, 2), "umol/m2/d")
# Out:
# Mean mean CH4 flux: 3.83 umol/m2/d +/- 3.55 umol/m2/d
#
# Transatlantic mean mean CH4 flux: 3.46 umol/m2/d +/- 3.62 umol/m2/d
#
# Labrador sea mean mean CH4 flux: 4.06 umol/m2/d +/- 4.86 umol/m2/d
#
# Greenland mean mean CH4 flux: 4.45 umol/m2/d +/- 2.36 umol/m2/d
#
# Labrador + Greenland mean mean CH4 flux: 4.29 umol/m2/d +/- 3.5 umol/m2/d

# %% [markdown]
# ### Dissolved (water) concentration

# %%
#CO2
#overrall mean values
mean_co2_mmolm3 = np.mean(data['co2_mmolm3'])
std_dev_mean_co2_mmolm3 = np.std(data['co2_mmolm3'], ddof=1)
print("Mean dissolved CO2:", mean_co2_mmolm3.round(2), "mmol/m3 +/-", round(std_dev_mean_co2_mmolm3, 2), "mmol/m3", "\n")

#mean value of transatlantic samples
mean_co2_mmolm3_transat = np.mean(data['co2_mmolm3'][0:27])
std_dev_mean_co2_mmolm3_transat = np.std(data['co2_mmolm3'][0:27], ddof=1)
print("Transatlantic mean dissolved CO2:", mean_co2_mmolm3_transat.round(2), "mmol/m3 +/-", round(std_dev_mean_co2_mmolm3_transat, 2), "mmol/m3", "\n")

#mean value of Labrador sea samples
mean_co2_mmolm3_labrador = np.mean(data['co2_mmolm3'][27:36])
std_dev_mean_co2_mmolm3_labrador = np.std(data['co2_mmolm3'][27:36], ddof=1)
print("Labrador sea mean dissolved CO2:", mean_co2_mmolm3_labrador.round(2), "mmol/m3 +/-", round(std_dev_mean_co2_mmolm3_labrador, 2), "mmol/m3", "\n")

#mean value of Greeanland samples
mean_co2_mmolm3_greenland = np.mean(data['co2_mmolm3'][36:])
std_dev_mean_co2_mmolm3_greenland = np.std(data['co2_mmolm3'][36:], ddof=1)
print("Greenland mean dissolved CO2:", mean_co2_mmolm3_greenland.round(2), "mmol/m3 +/-", round(std_dev_mean_co2_mmolm3_greenland, 2), "mmol/m3")
# Out:
# Mean dissolved CO2: 15.92 mmol/m3 +/- 3.35 mmol/m3
#
# Transatlantic mean dissolved CO2: 13.54 mmol/m3 +/- 1.75 mmol/m3
#
# Labrador sea mean dissolved CO2: 17.6 mmol/m3 +/- 2.3 mmol/m3
#
# Greenland mean dissolved CO2: 19.69 mmol/m3 +/- 2.09 mmol/m3

# %%
#CH4
#overrall mean values
mean_ch4_umolm3 = np.mean(data['ch4_umolm3'])
std_dev_mean_ch4_umolm3 = np.std(data['ch4_umolm3'], ddof=1)
print("Mean dissolved CH4:", mean_ch4_umolm3.round(2), "umol/m3 +/-", round(std_dev_mean_ch4_umolm3, 2), "umol/m3", "\n")

#mean value of transatlantic samples
mean_ch4_umolm3_transat = np.mean(data['ch4_umolm3'][0:27])
std_dev_mean_ch4_umolm3_transat = np.std(data['ch4_umolm3'][0:27], ddof=1)
print("Transatlantic mean dissolved CH4:", mean_ch4_umolm3_transat.round(2), "umol/m3 +/-", round(std_dev_mean_ch4_umolm3_transat, 2), "umol/m3", "\n")

#mean value of Labrador sea samples
mean_ch4_umolm3_labrador = np.mean(data['ch4_umolm3'][27:36])
std_dev_mean_ch4_umolm3_labrador = np.std(data['ch4_umolm3'][27:36], ddof=1)
print("Labrador sea mean dissolved CH4:", mean_ch4_umolm3_labrador.round(2), "umol/m3 +/-", round(std_dev_mean_ch4_umolm3_labrador, 2), "umol/m3", "\n")

#mean value of Greeanland samples
mean_ch4_umolm3_greenland = np.mean(data['ch4_umolm3'][36:])
std_dev_mean_ch4_umolm3_greenland = np.std(data['ch4_umolm3'][36:], ddof=1)
print("Greenland mean dissolved CH4:", mean_ch4_umolm3_greenland.round(2), "umol/m3 +/-", round(std_dev_mean_ch4_umolm3_greenland, 2), "umol/m3",)
# Out:
# Mean dissolved CH4: 3.48 umol/m3 +/- 1.24 umol/m3
#
# Transatlantic mean dissolved CH4: 2.8 umol/m3 +/- 0.88 umol/m3
#
# Labrador sea mean dissolved CH4: 3.73 umol/m3 +/- 1.2 umol/m3
#
# Greenland mean dissolved CH4: 4.69 umol/m3 +/- 0.9 umol/m3

# %% [markdown]
# ### Atmopheric concentration

# %%
#CO2
#overrall mean values
mean_CO2atm_ppm = np.mean(data['CO2atm_ppm'])
std_dev_mean_CO2atm_ppm = np.std(data['CO2atm_ppm'], ddof=1)
#n = len(data['CO2atm_ppm'])
#SEM = std_dev_mean_CO2atm_ppm / np.sqrt(n)
print("Mean atmospheric CO2:", mean_CO2atm_ppm.round(2), "ppm +/-", round(std_dev_mean_CO2atm_ppm, 2) , "ppm", "\n")

#mean value of transatlantic samples
mean_CO2atm_ppm_transat = np.mean(data['CO2atm_ppm'][0:27])
std_dev_mean_CO2atm_ppm_transat = np.std(data['CO2atm_ppm'][0:27], ddof=1)
print("Transatlantic mean atmospheric CO2:", mean_CO2atm_ppm_transat.round(2), "ppm +/-", round(std_dev_mean_CO2atm_ppm_transat, 2), "ppm", "\n")

#mean value of Labrador sea samples
mean_CO2atm_ppm_labrador = np.mean(data['CO2atm_ppm'][27:36])
std_dev_mean_CO2atm_ppm_labrador = np.std(data['CO2atm_ppm'][27:36], ddof=1)
print("Labrador sea mean atmospheric CO2:", mean_CO2atm_ppm_labrador.round(2), "ppm +/-", round(std_dev_mean_CO2atm_ppm_labrador, 2), "ppm", "\n")

#mean value of Greeanland samples
mean_CO2atm_ppm_greenland = np.mean(data['CO2atm_ppm'][36:])
std_dev_mean_CO2atm_ppm_greenland = np.std(data['CO2atm_ppm'][36:], ddof=1)
print("Greenland mean atmospheric CO2:", mean_CO2atm_ppm_greenland.round(2), "ppm +/-", round(std_dev_mean_CO2atm_ppm_greenland, 2), "ppm",)
# Out:
# Mean atmospheric CO2: 430.91 ppm +/- 18.28 ppm
#
# Transatlantic mean atmospheric CO2: 434.84 ppm +/- 23.22 ppm
#
# Labrador sea mean atmospheric CO2: 426.92 ppm +/- 6.99 ppm
#
# Greenland mean atmospheric CO2: 425.52 ppm +/- 7.55 ppm

# %%
#CH4
#overrall mean values
mean_CH4atm_ppm = np.mean(data['CH4atm_ppm'])
std_dev_mean_CH4atm_ppm = np.std(data['CH4atm_ppm'], ddof=1)
print("Mean atmospheric CH4:", mean_CH4atm_ppm.round(2), "ppm +/-", round(std_dev_mean_CH4atm_ppm, 2), "ppm", "\n")

#mean value of transatlantic samples
mean_CH4atm_ppm_transat = np.mean(data['CH4atm_ppm'][0:27])
std_dev_mean_CH4atm_ppm_transat = np.std(data['CH4atm_ppm'][0:27], ddof=1)
print("Transatlantic mean atmospheric CH4:", mean_CH4atm_ppm_transat.round(2), "ppm +/-", round(std_dev_mean_CH4atm_ppm_transat, 2), "ppm", "\n")

#mean value of Labrador sea samples
mean_CH4atm_ppm_labrador = np.mean(data['CH4atm_ppm'][27:36])
std_dev_mean_CH4atm_ppm_labrador = np.std(data['CH4atm_ppm'][27:36], ddof=1)
print("Labrador sea mean atmospheric CH4:", mean_CH4atm_ppm_labrador.round(2), "ppm +/-", round(std_dev_mean_CH4atm_ppm_labrador, 2), "ppm", "\n")

#mean value of Greeanland samples
mean_CH4atm_ppm_greenland = np.mean(data['CH4atm_ppm'][36:])
std_dev_mean_CH4atm_ppm_greenland = np.std(data['CH4atm_ppm'][36:], ddof=1)
print("Greenland mean atmospheric CH4:", mean_CH4atm_ppm_greenland.round(2), "ppm +/-", round(std_dev_mean_CH4atm_ppm_greenland, 2), "ppm",)
# Out:
# Mean atmospheric CH4: 1.86 ppm +/- 0.06 ppm
#
# Transatlantic mean atmospheric CH4: 1.83 ppm +/- 0.05 ppm
#
# Labrador sea mean atmospheric CH4: 1.9 ppm +/- 0.03 ppm
#
# Greenland mean atmospheric CH4: 1.88 ppm +/- 0.05 ppm

# %% [markdown]
# ### Conversion of fluxes into annual fluxes

# %%
#First generate a dataframe with all values

df_fluxes = pd.DataFrame({
    'Mean_CO2_fluxes_mmolm2d' : [mean_F_mean_CO2_mmolm2d, mean_F_mean_CO2_transat, mean_F_mean_CO2_labrador, mean_F_mean_CO2_greenland],
    'Mean_CH4_fluxes_umolm2d' : [mean_F_mean_CH4_umolm2d, mean_F_mean_CH4_transat, mean_F_mean_CH4_labrador, mean_F_mean_CH4_greenland],
                          })

df_fluxes.index = ['Overall', 'Transatlantic', 'Labrador Sea', 'Greenland']

display(df_fluxes)
# Out:
#                Mean_CO2_fluxes_mmolm2d  Mean_CH4_fluxes_umolm2d
# Overall                      -3.402655                 3.832568
# Transatlantic                 5.302075                 3.459005
# Labrador Sea                -26.445958                 4.064841
# Greenland                    -5.528653                 4.447625

# %%
Mean_CO2_fluxes_gCm2y = df_fluxes['Mean_CO2_fluxes_mmolm2d'] * 10**(-3) * M_C_gmol * 365
Mean_CH4_fluxes_gCm2y = df_fluxes['Mean_CH4_fluxes_umolm2d'] * 10**(-6) * M_C_gmol * 365
df_fluxes['Mean_CO2_fluxes_gCm2y'] = Mean_CO2_fluxes_gCm2y
df_fluxes['Mean_CH4_fluxes_gCm2y'] = Mean_CH4_fluxes_gCm2y

display(df_fluxes)
# Out:
#                Mean_CO2_fluxes_mmolm2d  Mean_CH4_fluxes_umolm2d  \
# Overall                      -3.402655                 3.832568
# Transatlantic                 5.302075                 3.459005
# Labrador Sea                -26.445958                 4.064841
# Greenland                    -5.528653                 4.447625
#
#                Mean_CO2_fluxes_gCm2y  Mean_CH4_fluxes_gCm2y
# Overall                   -14.903629               0.016787
# Transatlantic              23.223088               0.015150
# Labrador Sea             -115.833298               0.017804
# Greenland                 -24.215501               0.019481

# %% [markdown]
# ## Plot of the fluxes

# %%
#CO2 fluxes

plt.figure(figsize=(12, 6))
#plt.scatter(df_CO2['Datetime'], df_CO2['Min CO2 flux [mmol/m2/d]'], marker='o', color = '#7cbcff', label='Min CO2 flux [mmol/m2/d]', zorder = 3)
#plt.scatter(df_CO2['Datetime'], df_CO2['Max CO2 flux [mmol/m2/d]'], marker='o', color = '#007cff',  label='Max CO2 flux [mmol/m2/d]', zorder = 3)
plt.scatter(df_CO2['Datetime'][:27], df_CO2['Mean CO2 flux [mmol/m2/d]'][:27], marker='o', color = '#ff8b00',  label='Transatlantic', zorder = 3)
plt.scatter(df_CO2['Datetime'][27:36], df_CO2['Mean CO2 flux [mmol/m2/d]'][27:36], marker='o', color = '#00ac00',  label='Labrador Sea', zorder = 3)
plt.scatter(df_CO2['Datetime'][36:], df_CO2['Mean CO2 flux [mmol/m2/d]'][36:], marker='o', color = '#0800ff',  label='Greenland', zorder = 3)
plt.axhline(y=0, color='#000000', linestyle='-', linewidth=1.5, zorder=2)

plt.title('Mean CO2 fluxes over time')
plt.xlabel('Datetime')
plt.ylabel('CO2 flux [mmol/m2/d]')
plt.xticks(rotation=90)
plt.grid(True, zorder=0)
plt.legend()

# Export as an image
plt.savefig(os.path.join('Results', 'CO2_flux.png' ), bbox_inches='tight', dpi=150)

plt.show()

# %%
#CH4 fluxes

plt.figure(figsize=(12, 6))
#plt.scatter(df_CH4['Datetime'], df_CH4['Min CH4 flux [umol/m2/d]'], marker='o', color = '#7cbcff', label='Min CH4 flux [umol/m2/d]', zorder = 2)
#plt.scatter(df_CH4['Datetime'], df_CH4['Max CH4 flux [umol/m2/d]'], marker='o', color = '#007cff',  label='Max CH4 flux [umol/m2/d]', zorder = 2)
plt.scatter(df_CH4['Datetime'][:27], df_CH4['Mean CH4 flux [umol/m2/d]'][:27], marker='o', color = '#ff8b00',  label='Transatlantic', zorder = 2)
plt.scatter(df_CH4['Datetime'][27:36], df_CH4['Mean CH4 flux [umol/m2/d]'][27:36], marker='o', color = '#00ac00',  label='Labrador Sea', zorder = 2)
plt.scatter(df_CH4['Datetime'][36:], df_CH4['Mean CH4 flux [umol/m2/d]'][36:], marker='o', color = '#0800ff',  label='Greenland', zorder = 2)
plt.axhline(y=0, color='#000000', linestyle='-', linewidth=1.5, zorder=2)

plt.title('Mean CH4 fluxes over time')
plt.xlabel('Datetime')
plt.ylabel('CH4 flux [umol/m2/d]')
plt.ylim(-20, 20)
plt.xticks(rotation=90)
plt.grid(True, zorder=0)
plt.legend()

# Export as an image
plt.savefig(os.path.join('Results', 'CH4_flux.png' ), bbox_inches='tight', dpi=150)

plt.show()

# %% [markdown]
# ## Map of the fluxes

# %%
# Compute the mean CO2/CH4 fluxes (from a duplicate perspective), ie mean mean CO2/CH4 fluxes (MM_CO2/CH4)
F_MM_CO2_mmolm2d = df_CO2.groupby('Datetime')['Mean CO2 flux [mmol/m2/d]'].mean().reset_index()
F_MM_CO2_mmolm2d.rename(columns={'Mean CO2 flux [mmol/m2/d]': 'MM CO2 flux [mmol/m2/d]'}, inplace=True)
print(F_MM_CO2_mmolm2d)

F_MM_CH4_umolm2d = df_CH4.groupby('Datetime')['Mean CH4 flux [umol/m2/d]'].mean().reset_index()
F_MM_CH4_umolm2d.rename(columns={'Mean CH4 flux [umol/m2/d]': 'MM CH4 flux [umol/m2/d]'}, inplace=True)
print(F_MM_CH4_umolm2d)

# Merge the mean values back into the original DataFrame
df_CO2 = df_CO2.merge(F_MM_CO2_mmolm2d, on='Datetime', how='left')
df_CH4 = df_CH4.merge(F_MM_CH4_umolm2d, on='Datetime', how='left')
print(df_CO2.head())
print(df_CH4.head())
# Out:
#       Datetime  MM CO2 flux [mmol/m2/d]
# 0   2024_01_19                11.891953
# 1   2024_01_20                15.512275
# 2   2024_01_21                 2.560986
# 3   2024_01_22                 6.126190
# 4   2024_01_23                 2.951257
# 5   2024_01_24                 1.067636
# 6   2024_01_25                 4.479532
# 7   2024_01_26                 4.807366
# 8   2024_01_27                 4.892902
# 9   2024_01_28                 0.242258
# 10  2024_01_29                 2.985052
# 11  2024_01_30                 0.219311
# 12  2024_01_31                 1.213893
# 13  2024_02_01                11.286071
# 14  2024_02_02                 6.256442
# 15  2024_06_23               -22.001801
# 16  2024_06_24               -10.935690
# 17  2024_06_25               -10.664413
# 18  2024_06_26               -54.962635
# 19  2024_06_27               -25.910120
# 20  2024_07_18                -0.238227
# 21  2024_07_19                -3.117828
# ...

# %%
fig, ax = plt.subplots(subplot_kw={'projection': ccrs.LambertConformal(central_longitude=-40, central_latitude=50)}, figsize=(10, 10))

# Set map extent (focus on North Atlantic)
ax.set_extent([-75, -10, 5, 75], crs=ccrs.PlateCarree())

# Add map features
ax.add_feature(cfeature.OCEAN, color='lightblue')
ax.add_feature(cfeature.LAND.with_scale('50m'), facecolor="white")
ax.add_feature(cfeature.COASTLINE.with_scale('50m'))
ax.add_feature(cfeature.BORDERS, linestyle=":")

# Add grid lines
gl = ax.gridlines(draw_labels=True, dms=True, x_inline=False, y_inline=False, linestyle='--')
gl.top_labels = False
gl.right_labels = False

# Normalize the concentration values for color scaling
norm = mcolors.TwoSlopeNorm(vmin=df_CO2['MM CO2 flux [mmol/m2/d]'].min(), vcenter=0, vmax=df_CO2['MM CO2 flux [mmol/m2/d]'].max())
colormap = cm.get_cmap('RdBu_r')

# Plot the GPS points with color depending on concentration
for _, row in df_CO2.iterrows():
    rgba = colormap(norm(row['MM CO2 flux [mmol/m2/d]']))  # Get the color based on concentration
    hex_color = mcolors.to_hex(rgba)  # Convert to hex color
    ax.plot(row['Long'], row['Lat'], marker='o', markeredgecolor = 'black', markersize=6, color=hex_color, transform=ccrs.PlateCarree())

# Add colorbar legend
sm = cm.ScalarMappable(cmap=colormap, norm=norm)
sm.set_array([])  # Needed only for matplotlib < 3.1
cbar = plt.colorbar(sm, ax=ax, orientation='vertical', shrink=0.6, pad=0.05)
cbar.set_label('CO2 flux [mmol/m2/d]')

# Add title
plt.title("Mean CO2 fluxes")

# Export as an image
plt.savefig(os.path.join('Results', 'Map_CO2_flux.png' ), bbox_inches='tight', dpi=150)

# Show the plot
plt.show()
# Out:
# C:\Users\lolap\AppData\Local\Temp\ipykernel_19312\4057014185.py:19: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colormap = cm.get_cmap('RdBu_r')

# %%
fig, ax = plt.subplots(subplot_kw={'projection': ccrs.LambertConformal(central_longitude=-40, central_latitude=50)}, figsize=(10, 10))

# Set map extent (focus on North Atlantic)
ax.set_extent([-75, -10, 5, 75], crs=ccrs.PlateCarree())

# Add map features
ax.add_feature(cfeature.OCEAN, color='lightblue')
ax.add_feature(cfeature.LAND.with_scale('50m'), facecolor="white")
ax.add_feature(cfeature.COASTLINE.with_scale('50m'))
ax.add_feature(cfeature.BORDERS, linestyle=":")

# Add grid lines
gl = ax.gridlines(draw_labels=True, dms=True, x_inline=False, y_inline=False, linestyle='--')
gl.top_labels = False
gl.right_labels = False

# Normalize the concentration values for color scaling
norm = mcolors.TwoSlopeNorm(vmin=-5, vcenter=0, vmax=df_CH4['MM CH4 flux [umol/m2/d]'].max())
colormap = cm.get_cmap('RdBu_r')

# Plot the GPS points with color depending on concentration
for _, row in df_CH4.iterrows():
    rgba = colormap(norm(row['MM CH4 flux [umol/m2/d]']))  # Get the color based on concentration
    hex_color = mcolors.to_hex(rgba)  # Convert to hex color
    ax.plot(row['Long'], row['Lat'], marker='o', markeredgecolor = 'black', markersize=6, color=hex_color, transform=ccrs.PlateCarree())

# Add colorbar legend
sm = cm.ScalarMappable(cmap=colormap, norm=norm)
sm.set_array([])  # Needed only for matplotlib < 3.1
cbar = plt.colorbar(sm, ax=ax, orientation='vertical', shrink=0.6, pad=0.05)
cbar.set_label('CH4 flux [umol/m2/d]')

# Add title
plt.title("Mean CH4 fluxes")

# Export as an image
plt.savefig(os.path.join('Results', 'Map_CH4_flux.png' ), bbox_inches='tight', dpi=150)

# Show the plot
plt.show()
# Out:
# C:\Users\lolap\AppData\Local\Temp\ipykernel_19312\3032107143.py:19: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colormap = cm.get_cmap('RdBu_r')

# %% [markdown]
# ### Boxplot

# %%
#CO2
T = df_CO2['Mean CO2 flux [mmol/m2/d]'][:27] # T = transat
LS = df_CO2['Mean CO2 flux [mmol/m2/d]'][27:36] # LS = Labrdor Sea
G = df_CO2['Mean CO2 flux [mmol/m2/d]'][36:] # G = Greeanland
O = df_CO2['Mean CO2 flux [mmol/m2/d]'] # O = overall

# Combine the three subsets into one list
boxplot_CO2 = [T, LS, G, O]

plt.boxplot(boxplot_CO2, showmeans = True, meanline = True)
plt.xticks([1, 2, 3, 4], ['Transatlantic', 'Labrador Sea', 'Greenland', 'Overall']) 
plt.title("CO2 fluxes")
plt.ylabel("CO2 fluxes [mmol/m2/d]")
plt.grid(axis='y')

# Export as an image
plt.savefig(os.path.join('Results', 'Boxplot_CO2.png' ), bbox_inches='tight', dpi=150)

plt.show()

# %%
#CH4
T = df_CH4['Mean CH4 flux [umol/m2/d]'][:27] # T = transat
LS = df_CH4['Mean CH4 flux [umol/m2/d]'][27:36] # LS = Labrdor Sea
G = df_CH4['Mean CH4 flux [umol/m2/d]'][36:] # G = Greeanland
O = df_CH4['Mean CH4 flux [umol/m2/d]'] # O = overall

# Combine the three subsets into one list
boxplot_CH4 = [T, LS, G, O]

plt.boxplot(boxplot_CH4, showmeans = True, meanline = True)
plt.xticks([1, 2, 3, 4], ['Transatlantic', 'Labrador Sea', 'Greenland', 'Overall']) 
plt.title("CH4 fluxes")
plt.ylabel("CH4 fluxes [umol/m2/d]")
plt.grid(axis='y')
plt.legend()

# Export as an image
plt.savefig(os.path.join('Results', 'Boxplot_CH4.png' ), bbox_inches='tight', dpi=150)

plt.show()
# Out:
# C:\Users\lolap\AppData\Local\Temp\ipykernel_19312\295927038.py:15: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# ### Dissolved concentration with equilibrium concentration

# %%
#Compute the mean values for equ. concentration
mean_C_eq_CO2_molm3 = df_CO2.groupby('Datetime')['C_eq CO2 [molm3]'].mean().reset_index()
mean_C_eq_CO2_molm3.rename(columns={'C_eq CO2 [molm3]': 'mean_C_eq_CO2_molm3'}, inplace=True)
#print(mean_C_eq_CO2_molm3)

df_CO2 = df_CO2.merge(mean_C_eq_CO2_molm3, on='Datetime', how='left')
#print(df_CO2.head())

# %%
df_CO2['mean_C_eq_CO2_mmolm3'] = df_CO2['mean_C_eq_CO2_molm3'] * 10**3 #conversion from mol to mmol
#print(df_CO2.head())

# %%
#Overall dissolved CO2 concentration with the equilibrium concentration
plt.figure(figsize=(12, 6))
plt.scatter(data['Datetime'][:27], data['co2_mmolm3'][:27], marker='o', color = '#ff8b00', label='Transatlantic', zorder = 3)
plt.scatter(data['Datetime'][27:36], data['co2_mmolm3'][27:36], marker='o', color = '#00ac00', label='Labrador Sea', zorder = 3)
plt.scatter(data['Datetime'][36:], data['co2_mmolm3'][36:], marker='o', color = '#0008ff', label='Greenland', zorder = 3)
plt.plot(df_CO2['Datetime'], df_CO2['mean_C_eq_CO2_mmolm3'], color= '#e70000', label='Equilibrium concentration', zorder=2)

plt.title('Dissolved CO2 concentration')
plt.xlabel('Datetime')
plt.ylabel('Dissolved CO2 [mmol/m3]')
plt.xticks(rotation=90)
plt.grid(True, zorder=0)
plt.legend(loc = 'upper left')

# Export as an image
plt.savefig(os.path.join('Results', 'Dissolved_CO2.png' ), bbox_inches='tight', dpi=150)

plt.show()

# %%
#change of units: mmol/m3 --> umol/m3
data['ch4_umolm3'] = data['ch4_mmolm3'] * 10**3 
#print(data.head())

# %%
#Compute the mean values for equ. concentration
mean_C_eq_CH4_molm3 = df_CH4.groupby('Datetime')['C_eq CH4 [molm3]'].mean().reset_index()
mean_C_eq_CH4_molm3.rename(columns={'C_eq CH4 [molm3]': 'mean_C_eq_CH4_molm3'}, inplace=True)
#print(mean_C_eq_CH4_molm3)

df_CH4 = df_CH4.merge(mean_C_eq_CH4_molm3, on='Datetime', how='left')
#print(df_CH4.head())

# %%
df_CH4['mean_C_eq_CH4_umolm3'] = df_CH4['mean_C_eq_CH4_molm3'] * 10**6 #conversion from mol to mmol
#print(df_CH4.head())

# %%
plt.figure(figsize=(12, 6))
plt.scatter(data['Datetime'][:27], data['ch4_umolm3'][:27], marker='o', color = '#ff8b00', label='Transatlantic', zorder = 3)
plt.scatter(data['Datetime'][27:36], data['ch4_umolm3'][27:36], marker='o', color = '#00ac00', label='Labrador Sea', zorder = 3)
plt.scatter(data['Datetime'][36:], data['ch4_umolm3'][36:], marker='o', color = '#0008ff', label='Greenland', zorder = 3)
plt.plot(df_CH4['Datetime'], df_CH4['mean_C_eq_CH4_umolm3'], color= '#e70000', label='Equilibrium concentration', zorder=2)

plt.title('Dissolved CH4 concentration')
plt.xlabel('Datetime')
plt.ylabel('Dissolved CH4 [umol/m3]')
#plt.ylim(0, 10)
plt.xticks(rotation=90)
plt.grid(True, zorder=0)
plt.legend()

# Export as an image
plt.savefig(os.path.join('Results', 'Dissolved_CH4.png' ), bbox_inches='tight', dpi=150)

plt.show()

# %%
mean_WS = np.mean([metadata['Min_Wind_Speed [kts]'], metadata['Max_Wind_Speed [kts]']], axis = 0)
metadata['Mean_Wind_Speed [kts]'] = mean_WS

# Display the first rows
print(metadata.head())
# Out:
#          Sample_Name   Latitude  Longitude TWS [kts]  SOG [kts]  P_atm [hPa]  \
# 0  SLWT_2024_01_19_A  16.625000 -25.325000         7        4.5       1016.0
# 1  SLWT_2024_01_19_B  16.625000 -25.325000         7        4.5       1016.0
# 2  SLWT_2024_01_20_A  16.401667 -27.518333        16        7.6       1014.7
# 3  SLWT_2024_01_20_B  16.401667 -27.518333        16        7.6       1014.7
# 4  SLWT_2024_01_21_A  16.316667 -30.581667        19        7.5       1014.9
#
#    T_air [°C]   pH  Tw_b [°C]  Tw_a [°C] Mer [Douglas]  \
# 0        24.5  7.5       24.0       23.5             3
# 1        24.5  7.5       23.5       23.5             3
# 2        23.5  7.5       24.8       25.4           3-4
# 3        23.5  7.5       24.5       25.2           3-4
# 4        25.0  7.5       24.7       25.3             3
#
#                            Remarks  Min_Wind_Speed [kts]  \
# 0  Air pressure from NOAA archives                   7.0
# ...

# %% [markdown]
# ### Correlation matrix

# %%
df_correlation = pd.DataFrame({'Dissolved CO2' : data['co2_mmolm3'], 'CO2 flux' : df_CO2['Mean CO2 flux [mmol/m2/d]'], 'Saturated CO2' : df_CO2['mean_C_eq_CO2_mmolm3'],
                               'Dissolved CH4' : data['ch4_mmolm3'], 'CH4 flux' : df_CH4['Mean CH4 flux [umol/m2/d]'], 'Saturated CH4' : df_CH4['mean_C_eq_CH4_umolm3'],
                               'Salinity' : data['sal_psu'], 'Wind Speed' : metadata['Mean_Wind_Speed [kts]'], 
                               'Atm pressure' : metadata['P_atm [hPa]'], 'Sea surface temp' : metadata['Tw_b [°C]']
                                  })

# %%
corr_matrix = df_correlation.corr()

plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', center=0)
plt.title('Correlation Matrix')

# Export as an image
plt.savefig(os.path.join('Results', 'Corr_matrix.png' ), bbox_inches='tight', dpi=150)

plt.show()
